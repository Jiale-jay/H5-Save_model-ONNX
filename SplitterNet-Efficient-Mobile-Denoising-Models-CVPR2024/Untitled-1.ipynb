# %% [markdown]
# 随机生成十张带噪声的图片，并保存到本地。

# %%
#Randomly generate ten pictures with noise and save them locally.

import numpy as np
import matplotlib.pyplot as plt
import os

# 设置保存路径
modality = "original"  # 可选 "denoised" 或 "original"
images_path = "dataset/path/uncropped/" + modality + "/"  # 指定保存目录

# 确保目录存在
os.makedirs(images_path, exist_ok=True)

# 随机生成图像并保存
def generate_and_save_images(num_images=10, height=256, width=256):
    for i in range(num_images):
        # 随机生成图像
        image = np.random.rand(height, width, 3)  # 生成 RGB 图像
        save_path = os.path.join(images_path, f"random_image_{i+1}.png")

        # 保存图像
        plt.imsave(save_path, image)
        print(f"Saved: {save_path}")

# 调用函数生成并保存10张图像
generate_and_save_images(num_images=10, height=256, width=256)
# Out:
# Saved: dataset/path/uncropped/original/random_image_1.png
# Saved: dataset/path/uncropped/original/random_image_2.png
# Saved: dataset/path/uncropped/original/random_image_3.png
# Saved: dataset/path/uncropped/original/random_image_4.png
# Saved: dataset/path/uncropped/original/random_image_5.png
# Saved: dataset/path/uncropped/original/random_image_6.png
# Saved: dataset/path/uncropped/original/random_image_7.png
# Saved: dataset/path/uncropped/original/random_image_8.png
# Saved: dataset/path/uncropped/original/random_image_9.png
# Saved: dataset/path/uncropped/original/random_image_10.png

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# 设置保存路径
base_path = "dataset/path/uncropped/"
original_path = os.path.join(base_path, "original")
denoised_path = os.path.join(base_path, "denoised")

# 确保目录存在
os.makedirs(original_path, exist_ok=True)
os.makedirs(denoised_path, exist_ok=True)

# 随机生成图像并保存
def generate_and_save_images(num_images=20, height=256, width=256):
    for i in range(num_images):
        # 生成原始图像
        original_image = np.random.rand(height, width, 3)  # RGB 图像
        original_save_path = os.path.join(original_path, f"image_{i+1}.png")
        plt.imsave(original_save_path, original_image)
        print(f"Saved original: {original_save_path}")

        # 添加噪声
        noise = np.random.normal(0, 0.1, original_image.shape)  # 高斯噪声
        noisy_image = np.clip(original_image + noise, 0, 1)  # 添加噪声后裁剪到 [0, 1]
        noisy_save_path = os.path.join(denoised_path, f"image_{i+1}.png")
        plt.imsave(noisy_save_path, noisy_image)
        print(f"Saved noisy: {noisy_save_path}")

# 调用函数生成并保存图像
generate_and_save_images(num_images=20, height=256, width=256)

# %%
import tensorflow as tf
from models.SplitterNet import DYNUnet as SplitterNet  # 导入模型
import numpy as np

# 初始化模型
input_shape = (256, 256, 3)  # 模型输入大小
model = SplitterNet(input_shape=input_shape, num_filters=32)  # 创建模型实例

# 加载预训练权重
model.load_weights('model_weights/SplitterNet_MIDD_model.h5')

# 图像预处理函数
def load_image(image_path):
    img = tf.io.read_file(image_path)  # 读取图像
    img = tf.image.decode_png(img, channels=3)  # 解码为 RGB 图像
    img = tf.image.resize(img, (256, 256)) / 255.0  # 调整大小并归一化
    img = tf.expand_dims(img, 0)  # 增加批量维度
    return img

# 加载输入图像
noisy_image = load_image("dataset/uncropped/denoised/image_1.png")  # 替换为实际路径

# 使用模型进行去噪推理
output = model.predict(noisy_image)

# 保存去噪后的图像
output_image = tf.cast(output[0] * 255, tf.uint8)  # 将结果转为图像格式
tf.keras.preprocessing.image.save_img("output_denoised.png", output_image)  # 保存图像
print("去噪结果已保存到 output_denoised.png")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 7
#       5 # 初始化模型
#       6 input_shape = (256, 256, 3)  # 模型输入大小
# ----> 7 model = SplitterNet(input_shape=input_shape, num_filters=32)  # 创建模型实例
#       9 # 加载预训练权重
#      10 model.load_weights('model_weights/SplitterNet_MIDD_model.h5')
#
# File ~/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/models/SplitterNet.py:60, in DYNUnet(input_shape, num_filters)
#      55 x = layers.Conv2D(num_filters, kernel_size=3, strides=1, padding='same')(input)
#      57 # Encoder
#      58 # 1st stage
#      59 # 256x256x16
# ---> 60 split_tensor_1, split_tensor_2  = encoder_blk(x)
#      61 # 128x128x32
#      62 split_tensor_1 = tf.pad(split_tensor_1, [[0, 0], [1, 1], [1, 1], [0, 0]], 'REFLECT')
#
# File ~/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/models/SplitterNet.py:6, in encoder_blk(input)
#       5 def encoder_blk(input):
# ----> 6     split_tensors = split_using_slice(input)
#       7     split_tensor_1 = split_tensors[0]
#       8     split_tensor_2 = split_tensors[1]
#
# File ~/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/models/SplitterNet.py:12, in split_using_slice(tensor)
#      11 def split_using_slice(tensor):
# ---> 12     slice1 = tf.slice(tensor, [0, 0, 0, 0], [-1, -1, -1, tensor.shape[3] // 2])
#      13     slice2 = tf.slice(tensor, [0, 0, 0, tensor.shape[3] // 2], [-1, -1, -1, tensor.shape[3] // 2])
#      15     return slice1, slice2
#
# File ~/Learing/anaconda3/envs/CNN/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~/Learing/anaconda3/envs/CNN/lib/python3.10/site-packages/keras/src/backend/common/keras_tensor.py:138, in KerasTensor.__tf_tensor__(self, dtype, name)
#     137 def __tf_tensor__(self, dtype=None, name=None):
# --> 138     raise ValueError(
#     139         "A KerasTensor cannot be used as input to a TensorFlow function. "
#     140         "A KerasTensor is a symbolic placeholder for a shape and dtype, "
#     141         "used when constructing Keras Functional models "
#     142         "or Keras Functions. You can only use it as input to a Keras layer "
#     143         "or a Keras operation (from the namespaces `keras.layers` "
#     144         "and `keras.operations`). "
#     145         "You are likely doing something like:\n\n"
#     146         "```\n"
#     147         "x = Input(...)\n"
#     148         "...\n"
#     149         "tf_fn(x)  # Invalid.\n"
#     150         "```\n\n"
#     151         "What you should do instead is wrap `tf_fn` in a layer:\n\n"
#     152         "```\n"
#     153         "class MyLayer(Layer):\n"
#     154         "    def call(self, x):\n"
#     155         "        return tf_fn(x)\n\n"
#     156         "x = MyLayer()(x)\n"
#     157         "```\n"
#     158     )
#
# ValueError: A KerasTensor cannot be used as input to a TensorFlow function. A KerasTensor is a symbolic placeholder for a shape and dtype, used when constructing Keras Functional models or Keras Functions. You can only use it as input to a Keras layer or a Keras operation (from the namespaces `keras.layers` and `keras.operations`). You are likely doing something like:
#
# ```
# x = Input(...)
# ...
# tf_fn(x)  # Invalid.
# ```
#
# What you should do instead is wrap `tf_fn` in a layer:
#
# ```
# class MyLayer(Layer):
#     def call(self, x):
#         return tf_fn(x)
#
# x = MyLayer()(x)
# ```

# %%
import os
from glob import glob

test_set_dir = "/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped"
print(glob(os.path.join(test_set_dir+"/original/", "*")))
print(glob(os.path.join(test_set_dir+"/denoised/", "*")))
# Out:
# ['/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/original/image_15.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/original/image_14.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/original/image_16.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/original/image_17.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/original/image_13.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/original/image_12.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/original/image_10.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/original/image_11.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/original/image_8.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/original/image_9.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/original/image_2.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/original/image_3.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/original/image_1.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/original/image_4.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/original/image_5.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/original/image_7.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/original/image_6.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/original/image_20.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/original/image_19.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/original/image_18.png']
# ['/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/denoised/image_15.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/denoised/image_14.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/denoised/image_16.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/denoised/image_17.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/denoised/image_13.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/denoised/image_12.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/denoised/image_10.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/denoised/image_11.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/denoised/image_8.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/denoised/image_9.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/denoised/image_2.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/denoised/image_3.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/denoised/image_1.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/denoised/image_4.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/denoised/image_5.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/denoised/image_7.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/denoised/image_6.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/denoised/image_20.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/denoised/image_19.png', '/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped/denoised/image_18.png']

# %%
import tensorflow as tf
import os

# 设置模型路径
model_path = "/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/model_weights/SplitterNet_MIDD_model.h5"

# 检查路径是否存在
if os.path.exists(model_path):
    print("模型路径存在，开始加载模型...")
    try:
        # 注册自定义层或操作
        custom_objects = {
            "TFOpLambda": tf.keras.layers.Lambda  # 将 'TFOpLambda' 映射到 Lambda 层
        }

        # 加载模型时添加 custom_objects
        model = tf.keras.models.load_model(model_path, compile=False, custom_objects=custom_objects)
        
        # 输出模型结构
        model.summary()
        print("模型加载成功！")
    except Exception as e:
        print(f"模型加载失败：{e}")
else:
    print("模型路径不存在，请检查路径是否正确！")
# Out:
# 模型路径存在，开始加载模型...
# 模型加载失败：'function_type'

# %%
#Convert the model to saved_model
import tensorflow as tf
model = tf.keras.models.load_model("/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/model_weights/SplitterNet_MIDD_model.h5", compile=False)
model.save("/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/model_weights/saved_model", save_format='tf')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: /Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/model_weights/saved_model/assets
# INFO:tensorflow:Assets written to: /Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/model_weights/saved_model/assets

# %%
model = tf.keras.models.load_model("/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/model_weights/saved_model")
model.summary()
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]      0         []
#
#  conv2d (Conv2D)             (None, None, None, 32)       896       ['input_1[0][0]']
#
#  tf.slice (TFOpLambda)       (None, None, None, 16)       0         ['conv2d[0][0]']
#
#  tf.slice_1 (TFOpLambda)     (None, None, None, 16)       0         ['conv2d[0][0]']
#
#  tf.compat.v1.pad (TFOpLamb  (None, None, None, 16)       0         ['tf.slice[0][0]']
#  da)
#
#  tf.compat.v1.pad_1 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_1[0][0]']
#  mbda)
#
#  conv2d_1 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad[0][0]']
#
#  conv2d_2 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_1[0][0]']
#
#  leaky_re_lu (LeakyReLU)     (None, None, None, 32)       0         ['conv2d_1[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_2[0][0]']
#
#  tf.slice_2 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu[0][0]']
#
#  tf.slice_3 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu[0][0]']
#
#  tf.slice_4 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu_1[0][0]']
#
#  tf.slice_5 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu_1[0][0]']
#
#  tf.compat.v1.pad_2 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_2[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_3 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_3[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_4 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_4[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_5 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_5[0][0]']
#  mbda)
#
#  conv2d_3 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_2[0][0]']
#
#  conv2d_4 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_3[0][0]']
#
#  conv2d_5 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_4[0][0]']
#
#  conv2d_6 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_5[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_3[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_4[0][0]']
#
#  leaky_re_lu_4 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_5[0][0]']
#
#  leaky_re_lu_5 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_6[0][0]']
#
#  tf.slice_6 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu_2[0][0]']
#
#  tf.slice_7 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu_2[0][0]']
#
#  tf.slice_8 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu_3[0][0]']
#
#  tf.slice_9 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu_3[0][0]']
#
#  tf.slice_10 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_4[0][0]']
#
#  tf.slice_11 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_4[0][0]']
#
#  tf.slice_12 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_5[0][0]']
#
#  tf.slice_13 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_5[0][0]']
#
#  tf.compat.v1.pad_6 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_6[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_7 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_7[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_8 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_8[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_9 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_9[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_10 (TFOpL  (None, None, None, 16)       0         ['tf.slice_10[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_11 (TFOpL  (None, None, None, 16)       0         ['tf.slice_11[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_12 (TFOpL  (None, None, None, 16)       0         ['tf.slice_12[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_13 (TFOpL  (None, None, None, 16)       0         ['tf.slice_13[0][0]']
#  ambda)
#
#  conv2d_7 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_6[0][0]']
#
#  conv2d_8 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_7[0][0]']
#
#  conv2d_9 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_8[0][0]']
#
#  conv2d_10 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_10[0][0]']
#
#  conv2d_12 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_11[0][0]']
#
#  conv2d_13 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_12[0][0]']
#
#  conv2d_14 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_13[0][0]']
#
#  leaky_re_lu_6 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_7[0][0]']
#
#  leaky_re_lu_7 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_8[0][0]']
#
#  leaky_re_lu_8 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_9[0][0]']
#
#  leaky_re_lu_9 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_10[0][0]']
#
#  leaky_re_lu_10 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_11[0][0]']
#
#  leaky_re_lu_11 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_12[0][0]']
#
#  leaky_re_lu_12 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_13[0][0]']
#
#  leaky_re_lu_13 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_14[0][0]']
#
#  tf.slice_14 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_6[0][0]']
#
#  tf.slice_15 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_6[0][0]']
#
#  tf.slice_16 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_7[0][0]']
#
#  tf.slice_17 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_7[0][0]']
#
#  tf.slice_18 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_8[0][0]']
#
#  tf.slice_19 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_8[0][0]']
#
#  tf.slice_20 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_9[0][0]']
#
#  tf.slice_21 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_9[0][0]']
#
#  tf.slice_22 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_10[0][0]']
#
#  tf.slice_23 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_10[0][0]']
#
#  tf.slice_24 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_11[0][0]']
#
#  tf.slice_25 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_11[0][0]']
#
#  tf.slice_26 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_12[0][0]']
#
#  tf.slice_27 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_12[0][0]']
#
#  tf.slice_28 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_13[0][0]']
#
#  tf.slice_29 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_13[0][0]']
#
#  tf.compat.v1.pad_14 (TFOpL  (None, None, None, 16)       0         ['tf.slice_14[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_15 (TFOpL  (None, None, None, 16)       0         ['tf.slice_15[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_16 (TFOpL  (None, None, None, 16)       0         ['tf.slice_16[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_17 (TFOpL  (None, None, None, 16)       0         ['tf.slice_17[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_18 (TFOpL  (None, None, None, 16)       0         ['tf.slice_18[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_19 (TFOpL  (None, None, None, 16)       0         ['tf.slice_19[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_20 (TFOpL  (None, None, None, 16)       0         ['tf.slice_20[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_21 (TFOpL  (None, None, None, 16)       0         ['tf.slice_21[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_22 (TFOpL  (None, None, None, 16)       0         ['tf.slice_22[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_23 (TFOpL  (None, None, None, 16)       0         ['tf.slice_23[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_24 (TFOpL  (None, None, None, 16)       0         ['tf.slice_24[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_25 (TFOpL  (None, None, None, 16)       0         ['tf.slice_25[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_26 (TFOpL  (None, None, None, 16)       0         ['tf.slice_26[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_27 (TFOpL  (None, None, None, 16)       0         ['tf.slice_27[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_28 (TFOpL  (None, None, None, 16)       0         ['tf.slice_28[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_29 (TFOpL  (None, None, None, 16)       0         ['tf.slice_29[0][0]']
#  ambda)
#
#  conv2d_15 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_14[0][0]']
#
#  conv2d_16 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_15[0][0]']
#
#  conv2d_17 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_16[0][0]']
#
#  conv2d_18 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_17[0][0]']
#
#  conv2d_19 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_18[0][0]']
#
#  conv2d_20 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_19[0][0]']
#
#  conv2d_21 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_20[0][0]']
#
#  conv2d_22 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_21[0][0]']
#
#  conv2d_23 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_22[0][0]']
#
#  conv2d_24 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_23[0][0]']
#
#  conv2d_25 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_24[0][0]']
#
#  conv2d_26 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_25[0][0]']
#
#  conv2d_27 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_26[0][0]']
#
#  conv2d_28 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_27[0][0]']
#
#  conv2d_29 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_28[0][0]']
#
#  conv2d_30 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_29[0][0]']
#
#  leaky_re_lu_14 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_15[0][0]']
#
#  leaky_re_lu_15 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_16[0][0]']
#
#  leaky_re_lu_16 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_17[0][0]']
#
#  leaky_re_lu_17 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_18[0][0]']
#
#  leaky_re_lu_18 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_19[0][0]']
#
#  leaky_re_lu_19 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_20[0][0]']
#
#  leaky_re_lu_20 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_21[0][0]']
#
#  leaky_re_lu_21 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_22[0][0]']
#
#  leaky_re_lu_22 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_23[0][0]']
#
#  leaky_re_lu_23 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_24[0][0]']
#
#  leaky_re_lu_24 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_25[0][0]']
#
#  leaky_re_lu_25 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_26[0][0]']
#
#  leaky_re_lu_26 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_27[0][0]']
#
#  leaky_re_lu_27 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_28[0][0]']
#
#  leaky_re_lu_28 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_29[0][0]']
#
#  leaky_re_lu_29 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_30[0][0]']
#
#  tf.compat.v1.pad_30 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_14[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_33 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_15[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_36 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_16[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_39 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_17[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_42 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_18[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_45 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_19[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_48 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_20[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_51 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_21[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_54 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_22[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_57 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_23[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_60 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_24[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_63 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_25[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_66 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_26[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_69 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_27[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_72 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_28[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_75 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_29[0][0]']
#  ambda)
#
#  conv2d_31 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_30[0][0]']
#
#  conv2d_35 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_33[0][0]']
#
#  conv2d_39 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_36[0][0]']
#
#  conv2d_43 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_39[0][0]']
#
#  conv2d_47 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_42[0][0]']
#
#  conv2d_51 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_45[0][0]']
#
#  conv2d_55 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_48[0][0]']
#
#  conv2d_59 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_51[0][0]']
#
#  conv2d_63 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_54[0][0]']
#
#  conv2d_67 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_57[0][0]']
#
#  conv2d_71 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_60[0][0]']
#
#  conv2d_75 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_63[0][0]']
#
#  conv2d_79 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_66[0][0]']
#
#  conv2d_83 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_69[0][0]']
#
#  conv2d_87 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_72[0][0]']
#
#  conv2d_91 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_75[0][0]']
#
#  leaky_re_lu_30 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_31[0][0]']
#
#  leaky_re_lu_32 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_35[0][0]']
#
#  leaky_re_lu_34 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_39[0][0]']
#
#  leaky_re_lu_36 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_43[0][0]']
#
#  leaky_re_lu_38 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_47[0][0]']
#
#  leaky_re_lu_40 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_51[0][0]']
#
#  leaky_re_lu_42 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_55[0][0]']
#
#  leaky_re_lu_44 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_59[0][0]']
#
#  leaky_re_lu_46 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_63[0][0]']
#
#  leaky_re_lu_48 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_67[0][0]']
#
#  leaky_re_lu_50 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_71[0][0]']
#
#  leaky_re_lu_52 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_75[0][0]']
#
#  leaky_re_lu_54 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_79[0][0]']
#
#  leaky_re_lu_56 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_83[0][0]']
#
#  leaky_re_lu_58 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_87[0][0]']
#
#  leaky_re_lu_60 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_91[0][0]']
#
#  global_average_pooling2d (  (None, 32)                   0         ['leaky_re_lu_30[0][0]']
#  GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_32[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_2  (None, 32)                   0         ['leaky_re_lu_34[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_3  (None, 32)                   0         ['leaky_re_lu_36[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_4  (None, 32)                   0         ['leaky_re_lu_38[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_5  (None, 32)                   0         ['leaky_re_lu_40[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_6  (None, 32)                   0         ['leaky_re_lu_42[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_7  (None, 32)                   0         ['leaky_re_lu_44[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_8  (None, 32)                   0         ['leaky_re_lu_46[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_9  (None, 32)                   0         ['leaky_re_lu_48[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_50[0][0]']
#  0 (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_52[0][0]']
#  1 (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_54[0][0]']
#  2 (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_56[0][0]']
#  3 (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_58[0][0]']
#  4 (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_60[0][0]']
#  5 (GlobalAveragePooling2D)
#
#  tf.reshape (TFOpLambda)     (None, 1, 1, 32)             0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  tf.reshape_1 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  tf.reshape_2 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  tf.reshape_3 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_3[0
#                                                                     ][0]']
#
#  tf.reshape_4 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_4[0
#                                                                     ][0]']
#
#  tf.reshape_5 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_5[0
#                                                                     ][0]']
#
#  tf.reshape_6 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_6[0
#                                                                     ][0]']
#
#  tf.reshape_7 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_7[0
#                                                                     ][0]']
#
#  tf.reshape_8 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_8[0
#                                                                     ][0]']
#
#  tf.reshape_9 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_9[0
#                                                                     ][0]']
#
#  tf.reshape_10 (TFOpLambda)  (None, 1, 1, 32)             0         ['global_average_pooling2d_10[
#                                                                     0][0]']
#
#  tf.reshape_11 (TFOpLambda)  (None, 1, 1, 32)             0         ['global_average_pooling2d_11[
#                                                                     0][0]']
#
#  tf.reshape_12 (TFOpLambda)  (None, 1, 1, 32)             0         ['global_average_pooling2d_12[
#                                                                     0][0]']
#
#  tf.reshape_13 (TFOpLambda)  (None, 1, 1, 32)             0         ['global_average_pooling2d_13[
#                                                                     0][0]']
#
#  tf.reshape_14 (TFOpLambda)  (None, 1, 1, 32)             0         ['global_average_pooling2d_14[
#                                                                     0][0]']
#
# ...
#  conv2d_transpose_1 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_17[0][0]']
#  Transpose)
#
#  conv2d_transpose_2 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_18[0][0]']
#  Transpose)
#
#  conv2d_transpose_3 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_19[0][0]']
#  Transpose)
#
#  conv2d_transpose_4 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_20[0][0]']
#  Transpose)
#
#  conv2d_transpose_5 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_21[0][0]']
#  Transpose)
#
#  conv2d_transpose_6 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_22[0][0]']
#  Transpose)
#
#  conv2d_transpose_7 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_23[0][0]']
#  Transpose)
#
#  leaky_re_lu_62 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose[0][0]']
#
#  leaky_re_lu_63 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_1[0][0]']
#
#  leaky_re_lu_64 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_2[0][0]']
#
#  leaky_re_lu_65 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_3[0][0]']
#
#  leaky_re_lu_66 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_4[0][0]']
#
#  leaky_re_lu_67 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_5[0][0]']
#
#  leaky_re_lu_68 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_6[0][0]']
#
#  leaky_re_lu_69 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_7[0][0]']
#
#  tf.__operators__.add_32 (T  (None, None, None, 32)       0         ['leaky_re_lu_62[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_6[0][0]']
#
#  tf.__operators__.add_33 (T  (None, None, None, 32)       0         ['leaky_re_lu_63[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_7[0][0]']
#
#  tf.__operators__.add_34 (T  (None, None, None, 32)       0         ['leaky_re_lu_64[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_8[0][0]']
#
#  tf.__operators__.add_35 (T  (None, None, None, 32)       0         ['leaky_re_lu_65[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_9[0][0]']
#
#  tf.__operators__.add_36 (T  (None, None, None, 32)       0         ['leaky_re_lu_66[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_10[0][0]']
#
#  tf.__operators__.add_37 (T  (None, None, None, 32)       0         ['leaky_re_lu_67[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_11[0][0]']
#
#  tf.__operators__.add_38 (T  (None, None, None, 32)       0         ['leaky_re_lu_68[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_12[0][0]']
#
#  tf.__operators__.add_39 (T  (None, None, None, 32)       0         ['leaky_re_lu_69[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_13[0][0]']
#
#  tf.concat_24 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_32[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_33[0][0
#                                                                     ]']
#
#  tf.concat_25 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_34[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_35[0][0
#                                                                     ]']
#
#  tf.concat_26 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_36[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_37[0][0
#                                                                     ]']
#
#  tf.concat_27 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_38[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_39[0][0
#                                                                     ]']
#
#  conv2d_transpose_8 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_24[0][0]']
#  Transpose)
#
#  conv2d_transpose_9 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_25[0][0]']
#  Transpose)
#
#  conv2d_transpose_10 (Conv2  (None, None, None, 32)       18464     ['tf.concat_26[0][0]']
#  DTranspose)
#
#  conv2d_transpose_11 (Conv2  (None, None, None, 32)       18464     ['tf.concat_27[0][0]']
#  DTranspose)
#
#  leaky_re_lu_70 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_8[0][0]']
#
#  leaky_re_lu_71 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_9[0][0]']
#
#  leaky_re_lu_72 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_10[0][0]']
#
#  leaky_re_lu_73 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_11[0][0]']
#
#  tf.__operators__.add_40 (T  (None, None, None, 32)       0         ['leaky_re_lu_70[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_2[0][0]']
#
#  tf.__operators__.add_41 (T  (None, None, None, 32)       0         ['leaky_re_lu_71[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_3[0][0]']
#
#  tf.__operators__.add_42 (T  (None, None, None, 32)       0         ['leaky_re_lu_72[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_4[0][0]']
#
#  tf.__operators__.add_43 (T  (None, None, None, 32)       0         ['leaky_re_lu_73[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_5[0][0]']
#
#  tf.concat_28 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_40[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_41[0][0
#                                                                     ]']
#
#  tf.concat_29 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_42[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_43[0][0
#                                                                     ]']
#
#  conv2d_transpose_12 (Conv2  (None, None, None, 32)       18464     ['tf.concat_28[0][0]']
#  DTranspose)
#
#  conv2d_transpose_13 (Conv2  (None, None, None, 32)       18464     ['tf.concat_29[0][0]']
#  DTranspose)
#
#  leaky_re_lu_74 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_12[0][0]']
#
#  leaky_re_lu_75 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_13[0][0]']
#
#  tf.__operators__.add_44 (T  (None, None, None, 32)       0         ['leaky_re_lu_74[0][0]',
#  FOpLambda)                                                          'leaky_re_lu[0][0]']
#
#  tf.__operators__.add_45 (T  (None, None, None, 32)       0         ['leaky_re_lu_75[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_1[0][0]']
#
#  tf.concat_30 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_44[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_45[0][0
#                                                                     ]']
#
#  conv2d_transpose_14 (Conv2  (None, None, None, 32)       18464     ['tf.concat_30[0][0]']
#  DTranspose)
#
#  leaky_re_lu_76 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_14[0][0]']
#
#  tf.__operators__.add_46 (T  (None, None, None, 32)       0         ['leaky_re_lu_76[0][0]',
#  FOpLambda)                                                          'conv2d[0][0]']
#
#  conv2d_95 (Conv2D)          (None, None, None, 3)        867       ['tf.__operators__.add_46[0][0
#                                                                     ]']
#
#  tf.__operators__.add_47 (T  (None, None, None, 3)        0         ['input_1[0][0]',
#  FOpLambda)                                                          'conv2d_95[0][0]']
#
# ==================================================================================================
# Total params: 731059 (2.79 MB)
# Trainable params: 731059 (2.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
import numpy as np
test_input = np.random.rand(1,256, 256, 3)  # 假设输入大小为64x64x3
output = model.predict(test_input)
print(f"预测输出形状: {output.shape}")
# Out:
# 1/1 [==============================] - 0s 490ms/step
# 预测输出形状: (1, 256, 256, 3)

# %%
import tensorflow as tf
import numpy as np
import os
from skimage.metrics import structural_similarity as ssim
from skimage.metrics import peak_signal_noise_ratio as psnr
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
ls /Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/model_weights/
# Out:
# SplitterNet_MIDD_model.h5  keras_metadata.pb
# assets/                    saved_model.pb
# fingerprint.pb             variables/

# %%
ls /Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/model_weights/saved_model
# Out:
# assets/            keras_metadata.pb  variables/
# fingerprint.pb     saved_model.pb

# %%
import tensorflow as tf

# 加载已转换的 SavedModel
model = tf.keras.models.load_model("/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/model_weights/saved_model")

# 打印模型结构
model.summary()

# 测试模型输出
import numpy as np
test_input = np.random.rand(1, 64, 64, 3)  # 假设输入大小为64x64x3
output = model.predict(test_input)
print(f"预测输出形状: {output.shape}")
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]      0         []
#
#  conv2d (Conv2D)             (None, None, None, 32)       896       ['input_1[0][0]']
#
#  tf.slice (TFOpLambda)       (None, None, None, 16)       0         ['conv2d[0][0]']
#
#  tf.slice_1 (TFOpLambda)     (None, None, None, 16)       0         ['conv2d[0][0]']
#
#  tf.compat.v1.pad (TFOpLamb  (None, None, None, 16)       0         ['tf.slice[0][0]']
#  da)
#
#  tf.compat.v1.pad_1 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_1[0][0]']
#  mbda)
#
#  conv2d_1 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad[0][0]']
#
#  conv2d_2 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_1[0][0]']
#
#  leaky_re_lu (LeakyReLU)     (None, None, None, 32)       0         ['conv2d_1[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_2[0][0]']
#
#  tf.slice_2 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu[0][0]']
#
#  tf.slice_3 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu[0][0]']
#
#  tf.slice_4 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu_1[0][0]']
#
#  tf.slice_5 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu_1[0][0]']
#
#  tf.compat.v1.pad_2 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_2[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_3 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_3[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_4 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_4[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_5 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_5[0][0]']
#  mbda)
#
#  conv2d_3 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_2[0][0]']
#
#  conv2d_4 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_3[0][0]']
#
#  conv2d_5 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_4[0][0]']
#
#  conv2d_6 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_5[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_3[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_4[0][0]']
#
#  leaky_re_lu_4 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_5[0][0]']
#
#  leaky_re_lu_5 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_6[0][0]']
#
#  tf.slice_6 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu_2[0][0]']
#
#  tf.slice_7 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu_2[0][0]']
#
#  tf.slice_8 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu_3[0][0]']
#
#  tf.slice_9 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu_3[0][0]']
#
#  tf.slice_10 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_4[0][0]']
#
#  tf.slice_11 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_4[0][0]']
#
#  tf.slice_12 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_5[0][0]']
#
#  tf.slice_13 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_5[0][0]']
#
#  tf.compat.v1.pad_6 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_6[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_7 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_7[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_8 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_8[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_9 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_9[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_10 (TFOpL  (None, None, None, 16)       0         ['tf.slice_10[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_11 (TFOpL  (None, None, None, 16)       0         ['tf.slice_11[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_12 (TFOpL  (None, None, None, 16)       0         ['tf.slice_12[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_13 (TFOpL  (None, None, None, 16)       0         ['tf.slice_13[0][0]']
#  ambda)
#
#  conv2d_7 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_6[0][0]']
#
#  conv2d_8 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_7[0][0]']
#
#  conv2d_9 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_8[0][0]']
#
#  conv2d_10 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_10[0][0]']
#
#  conv2d_12 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_11[0][0]']
#
#  conv2d_13 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_12[0][0]']
#
#  conv2d_14 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_13[0][0]']
#
#  leaky_re_lu_6 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_7[0][0]']
#
#  leaky_re_lu_7 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_8[0][0]']
#
#  leaky_re_lu_8 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_9[0][0]']
#
#  leaky_re_lu_9 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_10[0][0]']
#
#  leaky_re_lu_10 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_11[0][0]']
#
#  leaky_re_lu_11 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_12[0][0]']
#
#  leaky_re_lu_12 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_13[0][0]']
#
#  leaky_re_lu_13 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_14[0][0]']
#
#  tf.slice_14 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_6[0][0]']
#
#  tf.slice_15 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_6[0][0]']
#
#  tf.slice_16 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_7[0][0]']
#
#  tf.slice_17 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_7[0][0]']
#
#  tf.slice_18 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_8[0][0]']
#
#  tf.slice_19 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_8[0][0]']
#
#  tf.slice_20 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_9[0][0]']
#
#  tf.slice_21 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_9[0][0]']
#
#  tf.slice_22 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_10[0][0]']
#
#  tf.slice_23 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_10[0][0]']
#
#  tf.slice_24 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_11[0][0]']
#
#  tf.slice_25 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_11[0][0]']
#
#  tf.slice_26 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_12[0][0]']
#
#  tf.slice_27 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_12[0][0]']
#
#  tf.slice_28 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_13[0][0]']
#
#  tf.slice_29 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_13[0][0]']
#
#  tf.compat.v1.pad_14 (TFOpL  (None, None, None, 16)       0         ['tf.slice_14[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_15 (TFOpL  (None, None, None, 16)       0         ['tf.slice_15[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_16 (TFOpL  (None, None, None, 16)       0         ['tf.slice_16[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_17 (TFOpL  (None, None, None, 16)       0         ['tf.slice_17[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_18 (TFOpL  (None, None, None, 16)       0         ['tf.slice_18[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_19 (TFOpL  (None, None, None, 16)       0         ['tf.slice_19[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_20 (TFOpL  (None, None, None, 16)       0         ['tf.slice_20[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_21 (TFOpL  (None, None, None, 16)       0         ['tf.slice_21[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_22 (TFOpL  (None, None, None, 16)       0         ['tf.slice_22[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_23 (TFOpL  (None, None, None, 16)       0         ['tf.slice_23[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_24 (TFOpL  (None, None, None, 16)       0         ['tf.slice_24[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_25 (TFOpL  (None, None, None, 16)       0         ['tf.slice_25[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_26 (TFOpL  (None, None, None, 16)       0         ['tf.slice_26[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_27 (TFOpL  (None, None, None, 16)       0         ['tf.slice_27[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_28 (TFOpL  (None, None, None, 16)       0         ['tf.slice_28[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_29 (TFOpL  (None, None, None, 16)       0         ['tf.slice_29[0][0]']
#  ambda)
#
#  conv2d_15 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_14[0][0]']
#
#  conv2d_16 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_15[0][0]']
#
#  conv2d_17 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_16[0][0]']
#
#  conv2d_18 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_17[0][0]']
#
#  conv2d_19 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_18[0][0]']
#
#  conv2d_20 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_19[0][0]']
#
#  conv2d_21 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_20[0][0]']
#
#  conv2d_22 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_21[0][0]']
#
#  conv2d_23 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_22[0][0]']
#
#  conv2d_24 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_23[0][0]']
#
#  conv2d_25 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_24[0][0]']
#
#  conv2d_26 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_25[0][0]']
#
#  conv2d_27 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_26[0][0]']
#
#  conv2d_28 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_27[0][0]']
#
#  conv2d_29 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_28[0][0]']
#
#  conv2d_30 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_29[0][0]']
#
#  leaky_re_lu_14 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_15[0][0]']
#
#  leaky_re_lu_15 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_16[0][0]']
#
#  leaky_re_lu_16 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_17[0][0]']
#
#  leaky_re_lu_17 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_18[0][0]']
#
#  leaky_re_lu_18 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_19[0][0]']
#
#  leaky_re_lu_19 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_20[0][0]']
#
#  leaky_re_lu_20 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_21[0][0]']
#
#  leaky_re_lu_21 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_22[0][0]']
#
#  leaky_re_lu_22 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_23[0][0]']
#
#  leaky_re_lu_23 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_24[0][0]']
#
#  leaky_re_lu_24 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_25[0][0]']
#
#  leaky_re_lu_25 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_26[0][0]']
#
#  leaky_re_lu_26 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_27[0][0]']
#
#  leaky_re_lu_27 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_28[0][0]']
#
#  leaky_re_lu_28 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_29[0][0]']
#
#  leaky_re_lu_29 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_30[0][0]']
#
#  tf.compat.v1.pad_30 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_14[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_33 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_15[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_36 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_16[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_39 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_17[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_42 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_18[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_45 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_19[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_48 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_20[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_51 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_21[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_54 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_22[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_57 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_23[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_60 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_24[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_63 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_25[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_66 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_26[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_69 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_27[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_72 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_28[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_75 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_29[0][0]']
#  ambda)
#
#  conv2d_31 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_30[0][0]']
#
#  conv2d_35 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_33[0][0]']
#
#  conv2d_39 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_36[0][0]']
#
#  conv2d_43 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_39[0][0]']
#
#  conv2d_47 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_42[0][0]']
#
#  conv2d_51 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_45[0][0]']
#
#  conv2d_55 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_48[0][0]']
#
#  conv2d_59 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_51[0][0]']
#
#  conv2d_63 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_54[0][0]']
#
#  conv2d_67 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_57[0][0]']
#
#  conv2d_71 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_60[0][0]']
#
#  conv2d_75 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_63[0][0]']
#
#  conv2d_79 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_66[0][0]']
#
#  conv2d_83 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_69[0][0]']
#
#  conv2d_87 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_72[0][0]']
#
#  conv2d_91 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_75[0][0]']
#
#  leaky_re_lu_30 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_31[0][0]']
#
#  leaky_re_lu_32 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_35[0][0]']
#
#  leaky_re_lu_34 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_39[0][0]']
#
#  leaky_re_lu_36 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_43[0][0]']
#
#  leaky_re_lu_38 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_47[0][0]']
#
#  leaky_re_lu_40 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_51[0][0]']
#
#  leaky_re_lu_42 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_55[0][0]']
#
#  leaky_re_lu_44 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_59[0][0]']
#
#  leaky_re_lu_46 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_63[0][0]']
#
#  leaky_re_lu_48 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_67[0][0]']
#
#  leaky_re_lu_50 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_71[0][0]']
#
#  leaky_re_lu_52 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_75[0][0]']
#
#  leaky_re_lu_54 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_79[0][0]']
#
#  leaky_re_lu_56 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_83[0][0]']
#
#  leaky_re_lu_58 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_87[0][0]']
#
#  leaky_re_lu_60 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_91[0][0]']
#
#  global_average_pooling2d (  (None, 32)                   0         ['leaky_re_lu_30[0][0]']
#  GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_32[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_2  (None, 32)                   0         ['leaky_re_lu_34[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_3  (None, 32)                   0         ['leaky_re_lu_36[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_4  (None, 32)                   0         ['leaky_re_lu_38[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_5  (None, 32)                   0         ['leaky_re_lu_40[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_6  (None, 32)                   0         ['leaky_re_lu_42[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_7  (None, 32)                   0         ['leaky_re_lu_44[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_8  (None, 32)                   0         ['leaky_re_lu_46[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_9  (None, 32)                   0         ['leaky_re_lu_48[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_50[0][0]']
#  0 (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_52[0][0]']
#  1 (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_54[0][0]']
#  2 (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_56[0][0]']
#  3 (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_58[0][0]']
#  4 (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_60[0][0]']
#  5 (GlobalAveragePooling2D)
#
#  tf.reshape (TFOpLambda)     (None, 1, 1, 32)             0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  tf.reshape_1 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  tf.reshape_2 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  tf.reshape_3 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_3[0
#                                                                     ][0]']
#
#  tf.reshape_4 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_4[0
#                                                                     ][0]']
#
#  tf.reshape_5 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_5[0
#                                                                     ][0]']
#
#  tf.reshape_6 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_6[0
#                                                                     ][0]']
#
#  tf.reshape_7 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_7[0
#                                                                     ][0]']
#
#  tf.reshape_8 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_8[0
#                                                                     ][0]']
#
#  tf.reshape_9 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_9[0
#                                                                     ][0]']
#
#  tf.reshape_10 (TFOpLambda)  (None, 1, 1, 32)             0         ['global_average_pooling2d_10[
#                                                                     0][0]']
#
#  tf.reshape_11 (TFOpLambda)  (None, 1, 1, 32)             0         ['global_average_pooling2d_11[
#                                                                     0][0]']
#
#  tf.reshape_12 (TFOpLambda)  (None, 1, 1, 32)             0         ['global_average_pooling2d_12[
#                                                                     0][0]']
#
#  tf.reshape_13 (TFOpLambda)  (None, 1, 1, 32)             0         ['global_average_pooling2d_13[
#                                                                     0][0]']
#
#  tf.reshape_14 (TFOpLambda)  (None, 1, 1, 32)             0         ['global_average_pooling2d_14[
#                                                                     0][0]']
#
# ...
#  Transpose)
#
#  conv2d_transpose_2 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_18[0][0]']
#  Transpose)
#
#  conv2d_transpose_3 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_19[0][0]']
#  Transpose)
#
#  conv2d_transpose_4 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_20[0][0]']
#  Transpose)
#
#  conv2d_transpose_5 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_21[0][0]']
#  Transpose)
#
#  conv2d_transpose_6 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_22[0][0]']
#  Transpose)
#
#  conv2d_transpose_7 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_23[0][0]']
#  Transpose)
#
#  leaky_re_lu_62 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose[0][0]']
#
#  leaky_re_lu_63 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_1[0][0]']
#
#  leaky_re_lu_64 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_2[0][0]']
#
#  leaky_re_lu_65 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_3[0][0]']
#
#  leaky_re_lu_66 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_4[0][0]']
#
#  leaky_re_lu_67 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_5[0][0]']
#
#  leaky_re_lu_68 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_6[0][0]']
#
#  leaky_re_lu_69 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_7[0][0]']
#
#  tf.__operators__.add_32 (T  (None, None, None, 32)       0         ['leaky_re_lu_62[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_6[0][0]']
#
#  tf.__operators__.add_33 (T  (None, None, None, 32)       0         ['leaky_re_lu_63[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_7[0][0]']
#
#  tf.__operators__.add_34 (T  (None, None, None, 32)       0         ['leaky_re_lu_64[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_8[0][0]']
#
#  tf.__operators__.add_35 (T  (None, None, None, 32)       0         ['leaky_re_lu_65[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_9[0][0]']
#
#  tf.__operators__.add_36 (T  (None, None, None, 32)       0         ['leaky_re_lu_66[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_10[0][0]']
#
#  tf.__operators__.add_37 (T  (None, None, None, 32)       0         ['leaky_re_lu_67[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_11[0][0]']
#
#  tf.__operators__.add_38 (T  (None, None, None, 32)       0         ['leaky_re_lu_68[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_12[0][0]']
#
#  tf.__operators__.add_39 (T  (None, None, None, 32)       0         ['leaky_re_lu_69[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_13[0][0]']
#
#  tf.concat_24 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_32[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_33[0][0
#                                                                     ]']
#
#  tf.concat_25 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_34[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_35[0][0
#                                                                     ]']
#
#  tf.concat_26 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_36[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_37[0][0
#                                                                     ]']
#
#  tf.concat_27 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_38[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_39[0][0
#                                                                     ]']
#
#  conv2d_transpose_8 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_24[0][0]']
#  Transpose)
#
#  conv2d_transpose_9 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_25[0][0]']
#  Transpose)
#
#  conv2d_transpose_10 (Conv2  (None, None, None, 32)       18464     ['tf.concat_26[0][0]']
#  DTranspose)
#
#  conv2d_transpose_11 (Conv2  (None, None, None, 32)       18464     ['tf.concat_27[0][0]']
#  DTranspose)
#
#  leaky_re_lu_70 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_8[0][0]']
#
#  leaky_re_lu_71 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_9[0][0]']
#
#  leaky_re_lu_72 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_10[0][0]']
#
#  leaky_re_lu_73 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_11[0][0]']
#
#  tf.__operators__.add_40 (T  (None, None, None, 32)       0         ['leaky_re_lu_70[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_2[0][0]']
#
#  tf.__operators__.add_41 (T  (None, None, None, 32)       0         ['leaky_re_lu_71[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_3[0][0]']
#
#  tf.__operators__.add_42 (T  (None, None, None, 32)       0         ['leaky_re_lu_72[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_4[0][0]']
#
#  tf.__operators__.add_43 (T  (None, None, None, 32)       0         ['leaky_re_lu_73[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_5[0][0]']
#
#  tf.concat_28 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_40[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_41[0][0
#                                                                     ]']
#
#  tf.concat_29 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_42[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_43[0][0
#                                                                     ]']
#
#  conv2d_transpose_12 (Conv2  (None, None, None, 32)       18464     ['tf.concat_28[0][0]']
#  DTranspose)
#
#  conv2d_transpose_13 (Conv2  (None, None, None, 32)       18464     ['tf.concat_29[0][0]']
#  DTranspose)
#
#  leaky_re_lu_74 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_12[0][0]']
#
#  leaky_re_lu_75 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_13[0][0]']
#
#  tf.__operators__.add_44 (T  (None, None, None, 32)       0         ['leaky_re_lu_74[0][0]',
#  FOpLambda)                                                          'leaky_re_lu[0][0]']
#
#  tf.__operators__.add_45 (T  (None, None, None, 32)       0         ['leaky_re_lu_75[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_1[0][0]']
#
#  tf.concat_30 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_44[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_45[0][0
#                                                                     ]']
#
#  conv2d_transpose_14 (Conv2  (None, None, None, 32)       18464     ['tf.concat_30[0][0]']
#  DTranspose)
#
#  leaky_re_lu_76 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_14[0][0]']
#
#  tf.__operators__.add_46 (T  (None, None, None, 32)       0         ['leaky_re_lu_76[0][0]',
#  FOpLambda)                                                          'conv2d[0][0]']
#
#  conv2d_95 (Conv2D)          (None, None, None, 3)        867       ['tf.__operators__.add_46[0][0
#                                                                     ]']
#
#  tf.__operators__.add_47 (T  (None, None, None, 3)        0         ['input_1[0][0]',
#  FOpLambda)                                                          'conv2d_95[0][0]']
#
# ==================================================================================================
# Total params: 731059 (2.79 MB)
# Trainable params: 731059 (2.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# 1/1 [==============================] - 1s 563ms/step
# 预测输出形状: (1, 64, 64, 3)

# %%
import tensorflow as tf
import numpy as np
from skimage.metrics import structural_similarity as ssim
from skimage.metrics import peak_signal_noise_ratio as psnr
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import os

# -------------------------------
# 1. calculate PSNR
def calculate_psnr(img1, img2):
    # 确保输入图像大小一致
    assert img1.shape == img2.shape, "图像尺寸必须一致才能计算PSNR！"
    return psnr(img1, img2, data_range=img1.max() - img1.min())

# 2. 计算 SSIM
def calculate_ssim(img1, img2):
    # 设置较小的窗口大小，并确保输入图像大小一致
    assert img1.shape == img2.shape, "图像尺寸必须一致才能计算SSIM！"
    return ssim(img1, img2, data_range=img1.max() - img1.min(), 
                win_size=3, channel_axis=-1)  # 设置 win_size 和通道轴
# -------------------------------

# 3. 加载模型
model_path = "/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/model_weights/saved_model"
model = tf.keras.models.load_model(model_path)
print("模型加载成功！")
model.summary()

# -------------------------------
# 4. 测试集路径
test_set_dir = "/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/dataset/path/uncropped"
original_dir = os.path.join(test_set_dir, "original/")
denoised_dir = os.path.join(test_set_dir, "denoised/")

# 确保路径存在
assert os.path.exists(original_dir), f"路径不存在: {original_dir}"
assert os.path.exists(denoised_dir), f"路径不存在: {denoised_dir}"

# 获取图像路径列表
original_images = sorted([os.path.join(original_dir, f) for f in os.listdir(original_dir)])
denoised_images = sorted([os.path.join(denoised_dir, f) for f in os.listdir(denoised_dir)])

# -------------------------------
# 5. 初始化存储结果
psnr_values = []
ssim_values = []

# 6. 遍历测试集图像
for orig_path, denoised_path in zip(original_images, denoised_images):
    # 加载图像并调整大小（至少7x7）
    orig_img = img_to_array(load_img(orig_path, target_size=(64, 64))) / 255.0
    denoised_img = img_to_array(load_img(denoised_path, target_size=(64, 64))) / 255.0

    # 确保图像大小和通道数一致
    assert orig_img.shape == denoised_img.shape, "输入图像和去噪图像大小必须一致！"

    # 模型预测
    input_img = np.expand_dims(orig_img, axis=0)
    predicted_img = model.predict(input_img)
    predicted_img = np.squeeze(predicted_img)  # 去除多余维度

    # 计算 PSNR 和 SSIM
    psnr_value = calculate_psnr(denoised_img, predicted_img)
    ssim_value = calculate_ssim(denoised_img, predicted_img)

    # 保存结果
    psnr_values.append(psnr_value)
    ssim_values.append(ssim_value)

    # 打印每张图片的评估结果
    print(f"{os.path.basename(orig_path)} -> PSNR: {psnr_value:.4f}, SSIM: {ssim_value:.4f}")

# -------------------------------
# 7. 打印总体平均结果
print(f"Average PSNR: {np.mean(psnr_values):.4f}")
print(f"Average SSIM: {np.mean(ssim_values):.4f}")
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# 模型加载成功！
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]      0         []
#
#  conv2d (Conv2D)             (None, None, None, 32)       896       ['input_1[0][0]']
#
#  tf.slice (TFOpLambda)       (None, None, None, 16)       0         ['conv2d[0][0]']
#
#  tf.slice_1 (TFOpLambda)     (None, None, None, 16)       0         ['conv2d[0][0]']
#
#  tf.compat.v1.pad (TFOpLamb  (None, None, None, 16)       0         ['tf.slice[0][0]']
#  da)
#
#  tf.compat.v1.pad_1 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_1[0][0]']
#  mbda)
#
#  conv2d_1 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad[0][0]']
#
#  conv2d_2 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_1[0][0]']
#
#  leaky_re_lu (LeakyReLU)     (None, None, None, 32)       0         ['conv2d_1[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_2[0][0]']
#
#  tf.slice_2 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu[0][0]']
#
#  tf.slice_3 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu[0][0]']
#
#  tf.slice_4 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu_1[0][0]']
#
#  tf.slice_5 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu_1[0][0]']
#
#  tf.compat.v1.pad_2 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_2[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_3 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_3[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_4 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_4[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_5 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_5[0][0]']
#  mbda)
#
#  conv2d_3 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_2[0][0]']
#
#  conv2d_4 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_3[0][0]']
#
#  conv2d_5 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_4[0][0]']
#
#  conv2d_6 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_5[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_3[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_4[0][0]']
#
#  leaky_re_lu_4 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_5[0][0]']
#
#  leaky_re_lu_5 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_6[0][0]']
#
#  tf.slice_6 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu_2[0][0]']
#
#  tf.slice_7 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu_2[0][0]']
#
#  tf.slice_8 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu_3[0][0]']
#
#  tf.slice_9 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu_3[0][0]']
#
#  tf.slice_10 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_4[0][0]']
#
#  tf.slice_11 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_4[0][0]']
#
#  tf.slice_12 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_5[0][0]']
#
#  tf.slice_13 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_5[0][0]']
#
#  tf.compat.v1.pad_6 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_6[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_7 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_7[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_8 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_8[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_9 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_9[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_10 (TFOpL  (None, None, None, 16)       0         ['tf.slice_10[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_11 (TFOpL  (None, None, None, 16)       0         ['tf.slice_11[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_12 (TFOpL  (None, None, None, 16)       0         ['tf.slice_12[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_13 (TFOpL  (None, None, None, 16)       0         ['tf.slice_13[0][0]']
#  ambda)
#
#  conv2d_7 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_6[0][0]']
#
#  conv2d_8 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_7[0][0]']
#
#  conv2d_9 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_8[0][0]']
#
#  conv2d_10 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_10[0][0]']
#
#  conv2d_12 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_11[0][0]']
#
#  conv2d_13 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_12[0][0]']
#
#  conv2d_14 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_13[0][0]']
#
#  leaky_re_lu_6 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_7[0][0]']
#
#  leaky_re_lu_7 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_8[0][0]']
#
#  leaky_re_lu_8 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_9[0][0]']
#
#  leaky_re_lu_9 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_10[0][0]']
#
#  leaky_re_lu_10 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_11[0][0]']
#
#  leaky_re_lu_11 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_12[0][0]']
#
#  leaky_re_lu_12 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_13[0][0]']
#
#  leaky_re_lu_13 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_14[0][0]']
#
#  tf.slice_14 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_6[0][0]']
#
#  tf.slice_15 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_6[0][0]']
#
#  tf.slice_16 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_7[0][0]']
#
#  tf.slice_17 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_7[0][0]']
#
#  tf.slice_18 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_8[0][0]']
#
#  tf.slice_19 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_8[0][0]']
#
#  tf.slice_20 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_9[0][0]']
#
#  tf.slice_21 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_9[0][0]']
#
#  tf.slice_22 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_10[0][0]']
#
#  tf.slice_23 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_10[0][0]']
#
#  tf.slice_24 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_11[0][0]']
#
#  tf.slice_25 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_11[0][0]']
#
#  tf.slice_26 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_12[0][0]']
#
#  tf.slice_27 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_12[0][0]']
#
#  tf.slice_28 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_13[0][0]']
#
#  tf.slice_29 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_13[0][0]']
#
#  tf.compat.v1.pad_14 (TFOpL  (None, None, None, 16)       0         ['tf.slice_14[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_15 (TFOpL  (None, None, None, 16)       0         ['tf.slice_15[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_16 (TFOpL  (None, None, None, 16)       0         ['tf.slice_16[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_17 (TFOpL  (None, None, None, 16)       0         ['tf.slice_17[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_18 (TFOpL  (None, None, None, 16)       0         ['tf.slice_18[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_19 (TFOpL  (None, None, None, 16)       0         ['tf.slice_19[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_20 (TFOpL  (None, None, None, 16)       0         ['tf.slice_20[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_21 (TFOpL  (None, None, None, 16)       0         ['tf.slice_21[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_22 (TFOpL  (None, None, None, 16)       0         ['tf.slice_22[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_23 (TFOpL  (None, None, None, 16)       0         ['tf.slice_23[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_24 (TFOpL  (None, None, None, 16)       0         ['tf.slice_24[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_25 (TFOpL  (None, None, None, 16)       0         ['tf.slice_25[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_26 (TFOpL  (None, None, None, 16)       0         ['tf.slice_26[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_27 (TFOpL  (None, None, None, 16)       0         ['tf.slice_27[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_28 (TFOpL  (None, None, None, 16)       0         ['tf.slice_28[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_29 (TFOpL  (None, None, None, 16)       0         ['tf.slice_29[0][0]']
#  ambda)
#
#  conv2d_15 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_14[0][0]']
#
#  conv2d_16 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_15[0][0]']
#
#  conv2d_17 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_16[0][0]']
#
#  conv2d_18 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_17[0][0]']
#
#  conv2d_19 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_18[0][0]']
#
#  conv2d_20 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_19[0][0]']
#
#  conv2d_21 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_20[0][0]']
#
#  conv2d_22 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_21[0][0]']
#
#  conv2d_23 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_22[0][0]']
#
#  conv2d_24 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_23[0][0]']
#
#  conv2d_25 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_24[0][0]']
#
#  conv2d_26 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_25[0][0]']
#
#  conv2d_27 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_26[0][0]']
#
#  conv2d_28 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_27[0][0]']
#
#  conv2d_29 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_28[0][0]']
#
#  conv2d_30 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_29[0][0]']
#
#  leaky_re_lu_14 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_15[0][0]']
#
#  leaky_re_lu_15 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_16[0][0]']
#
#  leaky_re_lu_16 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_17[0][0]']
#
#  leaky_re_lu_17 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_18[0][0]']
#
#  leaky_re_lu_18 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_19[0][0]']
#
#  leaky_re_lu_19 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_20[0][0]']
#
#  leaky_re_lu_20 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_21[0][0]']
#
#  leaky_re_lu_21 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_22[0][0]']
#
#  leaky_re_lu_22 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_23[0][0]']
#
#  leaky_re_lu_23 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_24[0][0]']
#
#  leaky_re_lu_24 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_25[0][0]']
#
#  leaky_re_lu_25 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_26[0][0]']
#
#  leaky_re_lu_26 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_27[0][0]']
#
#  leaky_re_lu_27 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_28[0][0]']
#
#  leaky_re_lu_28 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_29[0][0]']
#
#  leaky_re_lu_29 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_30[0][0]']
#
#  tf.compat.v1.pad_30 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_14[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_33 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_15[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_36 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_16[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_39 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_17[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_42 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_18[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_45 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_19[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_48 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_20[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_51 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_21[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_54 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_22[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_57 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_23[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_60 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_24[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_63 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_25[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_66 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_26[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_69 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_27[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_72 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_28[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_75 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_29[0][0]']
#  ambda)
#
#  conv2d_31 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_30[0][0]']
#
#  conv2d_35 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_33[0][0]']
#
#  conv2d_39 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_36[0][0]']
#
#  conv2d_43 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_39[0][0]']
#
#  conv2d_47 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_42[0][0]']
#
#  conv2d_51 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_45[0][0]']
#
#  conv2d_55 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_48[0][0]']
#
#  conv2d_59 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_51[0][0]']
#
#  conv2d_63 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_54[0][0]']
#
#  conv2d_67 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_57[0][0]']
#
#  conv2d_71 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_60[0][0]']
#
#  conv2d_75 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_63[0][0]']
#
#  conv2d_79 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_66[0][0]']
#
#  conv2d_83 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_69[0][0]']
#
#  conv2d_87 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_72[0][0]']
#
#  conv2d_91 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_75[0][0]']
#
#  leaky_re_lu_30 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_31[0][0]']
#
#  leaky_re_lu_32 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_35[0][0]']
#
#  leaky_re_lu_34 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_39[0][0]']
#
#  leaky_re_lu_36 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_43[0][0]']
#
#  leaky_re_lu_38 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_47[0][0]']
#
#  leaky_re_lu_40 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_51[0][0]']
#
#  leaky_re_lu_42 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_55[0][0]']
#
#  leaky_re_lu_44 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_59[0][0]']
#
#  leaky_re_lu_46 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_63[0][0]']
#
#  leaky_re_lu_48 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_67[0][0]']
#
#  leaky_re_lu_50 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_71[0][0]']
#
#  leaky_re_lu_52 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_75[0][0]']
#
#  leaky_re_lu_54 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_79[0][0]']
#
#  leaky_re_lu_56 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_83[0][0]']
#
#  leaky_re_lu_58 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_87[0][0]']
#
#  leaky_re_lu_60 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_91[0][0]']
#
#  global_average_pooling2d (  (None, 32)                   0         ['leaky_re_lu_30[0][0]']
#  GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_32[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_2  (None, 32)                   0         ['leaky_re_lu_34[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_3  (None, 32)                   0         ['leaky_re_lu_36[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_4  (None, 32)                   0         ['leaky_re_lu_38[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_5  (None, 32)                   0         ['leaky_re_lu_40[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_6  (None, 32)                   0         ['leaky_re_lu_42[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_7  (None, 32)                   0         ['leaky_re_lu_44[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_8  (None, 32)                   0         ['leaky_re_lu_46[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_9  (None, 32)                   0         ['leaky_re_lu_48[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_50[0][0]']
#  0 (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_52[0][0]']
#  1 (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_54[0][0]']
#  2 (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_56[0][0]']
#  3 (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_58[0][0]']
#  4 (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_60[0][0]']
#  5 (GlobalAveragePooling2D)
#
#  tf.reshape (TFOpLambda)     (None, 1, 1, 32)             0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  tf.reshape_1 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  tf.reshape_2 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  tf.reshape_3 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_3[0
#                                                                     ][0]']
#
#  tf.reshape_4 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_4[0
#                                                                     ][0]']
#
#  tf.reshape_5 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_5[0
#                                                                     ][0]']
#
#  tf.reshape_6 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_6[0
#                                                                     ][0]']
#
#  tf.reshape_7 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_7[0
#                                                                     ][0]']
#
#  tf.reshape_8 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_8[0
#                                                                     ][0]']
#
#  tf.reshape_9 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_9[0
#                                                                     ][0]']
#
#  tf.reshape_10 (TFOpLambda)  (None, 1, 1, 32)             0         ['global_average_pooling2d_10[
#                                                                     0][0]']
#
#  tf.reshape_11 (TFOpLambda)  (None, 1, 1, 32)             0         ['global_average_pooling2d_11[
#                                                                     0][0]']
#
#  tf.reshape_12 (TFOpLambda)  (None, 1, 1, 32)             0         ['global_average_pooling2d_12[
#                                                                     0][0]']
#
#  tf.reshape_13 (TFOpLambda)  (None, 1, 1, 32)             0         ['global_average_pooling2d_13[
#                                                                     0][0]']
#
#  tf.reshape_14 (TFOpLambda)  (None, 1, 1, 32)             0         ['global_average_pooling2d_14[
#                                                                     0][0]']
#
# ...
#
#  leaky_re_lu_69 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_7[0][0]']
#
#  tf.__operators__.add_32 (T  (None, None, None, 32)       0         ['leaky_re_lu_62[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_6[0][0]']
#
#  tf.__operators__.add_33 (T  (None, None, None, 32)       0         ['leaky_re_lu_63[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_7[0][0]']
#
#  tf.__operators__.add_34 (T  (None, None, None, 32)       0         ['leaky_re_lu_64[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_8[0][0]']
#
#  tf.__operators__.add_35 (T  (None, None, None, 32)       0         ['leaky_re_lu_65[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_9[0][0]']
#
#  tf.__operators__.add_36 (T  (None, None, None, 32)       0         ['leaky_re_lu_66[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_10[0][0]']
#
#  tf.__operators__.add_37 (T  (None, None, None, 32)       0         ['leaky_re_lu_67[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_11[0][0]']
#
#  tf.__operators__.add_38 (T  (None, None, None, 32)       0         ['leaky_re_lu_68[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_12[0][0]']
#
#  tf.__operators__.add_39 (T  (None, None, None, 32)       0         ['leaky_re_lu_69[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_13[0][0]']
#
#  tf.concat_24 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_32[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_33[0][0
#                                                                     ]']
#
#  tf.concat_25 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_34[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_35[0][0
#                                                                     ]']
#
#  tf.concat_26 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_36[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_37[0][0
#                                                                     ]']
#
#  tf.concat_27 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_38[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_39[0][0
#                                                                     ]']
#
#  conv2d_transpose_8 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_24[0][0]']
#  Transpose)
#
#  conv2d_transpose_9 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_25[0][0]']
#  Transpose)
#
#  conv2d_transpose_10 (Conv2  (None, None, None, 32)       18464     ['tf.concat_26[0][0]']
#  DTranspose)
#
#  conv2d_transpose_11 (Conv2  (None, None, None, 32)       18464     ['tf.concat_27[0][0]']
#  DTranspose)
#
#  leaky_re_lu_70 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_8[0][0]']
#
#  leaky_re_lu_71 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_9[0][0]']
#
#  leaky_re_lu_72 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_10[0][0]']
#
#  leaky_re_lu_73 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_11[0][0]']
#
#  tf.__operators__.add_40 (T  (None, None, None, 32)       0         ['leaky_re_lu_70[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_2[0][0]']
#
#  tf.__operators__.add_41 (T  (None, None, None, 32)       0         ['leaky_re_lu_71[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_3[0][0]']
#
#  tf.__operators__.add_42 (T  (None, None, None, 32)       0         ['leaky_re_lu_72[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_4[0][0]']
#
#  tf.__operators__.add_43 (T  (None, None, None, 32)       0         ['leaky_re_lu_73[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_5[0][0]']
#
#  tf.concat_28 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_40[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_41[0][0
#                                                                     ]']
#
#  tf.concat_29 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_42[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_43[0][0
#                                                                     ]']
#
#  conv2d_transpose_12 (Conv2  (None, None, None, 32)       18464     ['tf.concat_28[0][0]']
#  DTranspose)
#
#  conv2d_transpose_13 (Conv2  (None, None, None, 32)       18464     ['tf.concat_29[0][0]']
#  DTranspose)
#
#  leaky_re_lu_74 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_12[0][0]']
#
#  leaky_re_lu_75 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_13[0][0]']
#
#  tf.__operators__.add_44 (T  (None, None, None, 32)       0         ['leaky_re_lu_74[0][0]',
#  FOpLambda)                                                          'leaky_re_lu[0][0]']
#
#  tf.__operators__.add_45 (T  (None, None, None, 32)       0         ['leaky_re_lu_75[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_1[0][0]']
#
#  tf.concat_30 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_44[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_45[0][0
#                                                                     ]']
#
#  conv2d_transpose_14 (Conv2  (None, None, None, 32)       18464     ['tf.concat_30[0][0]']
#  DTranspose)
#
#  leaky_re_lu_76 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_14[0][0]']
#
#  tf.__operators__.add_46 (T  (None, None, None, 32)       0         ['leaky_re_lu_76[0][0]',
#  FOpLambda)                                                          'conv2d[0][0]']
#
#  conv2d_95 (Conv2D)          (None, None, None, 3)        867       ['tf.__operators__.add_46[0][0
#                                                                     ]']
#
#  tf.__operators__.add_47 (T  (None, None, None, 3)        0         ['input_1[0][0]',
#  FOpLambda)                                                          'conv2d_95[0][0]']
#
# ==================================================================================================
# Total params: 731059 (2.79 MB)
# Trainable params: 731059 (2.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x362d9a3b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x362d9a3b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 508ms/step
# image_1.png -> PSNR: 11.2961, SSIM: 0.1598
# 1/1 [==============================] - 0s 10ms/step
# image_10.png -> PSNR: 11.2648, SSIM: 0.1594
# 1/1 [==============================] - 0s 11ms/step
# image_11.png -> PSNR: 11.2439, SSIM: 0.1556
# 1/1 [==============================] - 0s 11ms/step
# image_12.png -> PSNR: 11.3056, SSIM: 0.1562
# 1/1 [==============================] - 0s 11ms/step
# image_13.png -> PSNR: 11.2666, SSIM: 0.1563
# 1/1 [==============================] - 0s 10ms/step
# image_14.png -> PSNR: 11.2494, SSIM: 0.1853
# 1/1 [==============================] - 0s 11ms/step
# image_15.png -> PSNR: 11.0839, SSIM: 0.1513
# 1/1 [==============================] - 0s 11ms/step
# image_16.png -> PSNR: 11.2745, SSIM: 0.1503
# 1/1 [==============================] - 0s 10ms/step
# image_17.png -> PSNR: 11.2791, SSIM: 0.1519
# 1/1 [==============================] - 0s 10ms/step
# image_18.png -> PSNR: 11.2711, SSIM: 0.1614
# 1/1 [==============================] - 0s 11ms/step
# image_19.png -> PSNR: 11.2184, SSIM: 0.1508
# 1/1 [==============================] - 0s 10ms/step
# image_2.png -> PSNR: 11.2491, SSIM: 0.1529
# 1/1 [==============================] - 0s 10ms/step
# image_20.png -> PSNR: 11.2095, SSIM: 0.1514
# 1/1 [==============================] - 0s 10ms/step
# image_3.png -> PSNR: 11.2719, SSIM: 0.1796
# 1/1 [==============================] - 0s 11ms/step
# image_4.png -> PSNR: 11.2802, SSIM: 0.1566
# 1/1 [==============================] - 0s 10ms/step
# image_5.png -> PSNR: 11.3371, SSIM: 0.1528
# 1/1 [==============================] - 0s 10ms/step
# image_6.png -> PSNR: 11.2635, SSIM: 0.1556
# 1/1 [==============================] - 0s 11ms/step
# image_7.png -> PSNR: 11.2996, SSIM: 0.1574
# 1/1 [==============================] - 0s 10ms/step
# image_8.png -> PSNR: 11.2894, SSIM: 0.1544
# 1/1 [==============================] - 0s 10ms/step
# image_9.png -> PSNR: 11.3766, SSIM: 0.1604
# Average PSNR: 11.2665
# Average SSIM: 0.1580

# %%
#Convert the model to saved_model
import tensorflow as tf
model = tf.keras.models.load_model("/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/model_weights/SplitterNet_MIDD_model.h5", compile=False)
model.save("/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/model_weights/saved_model", save_format='tf')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: /Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/model_weights/saved_model/assets
# INFO:tensorflow:Assets written to: /Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/model_weights/saved_model/assets

# %%
import tensorflow as tf
import tf2onnx
import onnx
import os

# 定义路径
saved_model_path = "model_weights/saved_model"  # SavedModel路径
onnx_model_path = "model_weights/SplitterNet_SavedModel.onnx"  # 转换后的ONNX路径

# 加载 SavedModel
model = tf.saved_model.load(saved_model_path)
print("SavedModel 加载成功！")

# 指定输入大小和数据类型
spec = (tf.TensorSpec((None, 64, 64, 3), tf.float32, name="input"),)  # 替换为模型实际输入尺寸

# 将 SavedModel 转换为 ONNX
onnx_model, _ = tf2onnx.convert.from_saved_model(
    saved_model_path,  # SavedModel 路径
    input_signature=spec,
    opset=13  # ONNX opset版本（推荐13或11）
)

# 保存转换后的 ONNX 模型
onnx.save_model(onnx_model, onnx_model_path)
print(f"模型已成功转换为 ONNX 格式，并保存到: {onnx_model_path}")
# Out:
# SavedModel 加载成功！
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 18
#      15 spec = (tf.TensorSpec((None, 64, 64, 3), tf.float32, name="input"),)  # 替换为模型实际输入尺寸
#      17 # 将 SavedModel 转换为 ONNX
# ---> 18 onnx_model, _ = tf2onnx.convert.from_saved_model(
#      19     saved_model_path,  # SavedModel 路径
#      20     input_signature=spec,
#      21     opset=13  # ONNX opset版本（推荐13或11）
#      22 )
#      24 # 保存转换后的 ONNX 模型
#      25 onnx.save_model(onnx_model, onnx_model_path)
#
# AttributeError: module 'tf2onnx.convert' has no attribute 'from_saved_model'

# %%
import tensorflow as tf

saved_model_path = "/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/model_weights/saved_model"
model = tf.keras.models.load_model(saved_model_path)  # 使用 Keras 加载
model.summary()
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]      0         []
#
#  conv2d (Conv2D)             (None, None, None, 32)       896       ['input_1[0][0]']
#
#  tf.slice (TFOpLambda)       (None, None, None, 16)       0         ['conv2d[0][0]']
#
#  tf.slice_1 (TFOpLambda)     (None, None, None, 16)       0         ['conv2d[0][0]']
#
#  tf.compat.v1.pad (TFOpLamb  (None, None, None, 16)       0         ['tf.slice[0][0]']
#  da)
#
#  tf.compat.v1.pad_1 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_1[0][0]']
#  mbda)
#
#  conv2d_1 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad[0][0]']
#
#  conv2d_2 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_1[0][0]']
#
#  leaky_re_lu (LeakyReLU)     (None, None, None, 32)       0         ['conv2d_1[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_2[0][0]']
#
#  tf.slice_2 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu[0][0]']
#
#  tf.slice_3 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu[0][0]']
#
#  tf.slice_4 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu_1[0][0]']
#
#  tf.slice_5 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu_1[0][0]']
#
#  tf.compat.v1.pad_2 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_2[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_3 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_3[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_4 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_4[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_5 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_5[0][0]']
#  mbda)
#
#  conv2d_3 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_2[0][0]']
#
#  conv2d_4 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_3[0][0]']
#
#  conv2d_5 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_4[0][0]']
#
#  conv2d_6 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_5[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_3[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_4[0][0]']
#
#  leaky_re_lu_4 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_5[0][0]']
#
#  leaky_re_lu_5 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_6[0][0]']
#
#  tf.slice_6 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu_2[0][0]']
#
#  tf.slice_7 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu_2[0][0]']
#
#  tf.slice_8 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu_3[0][0]']
#
#  tf.slice_9 (TFOpLambda)     (None, None, None, 16)       0         ['leaky_re_lu_3[0][0]']
#
#  tf.slice_10 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_4[0][0]']
#
#  tf.slice_11 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_4[0][0]']
#
#  tf.slice_12 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_5[0][0]']
#
#  tf.slice_13 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_5[0][0]']
#
#  tf.compat.v1.pad_6 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_6[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_7 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_7[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_8 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_8[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_9 (TFOpLa  (None, None, None, 16)       0         ['tf.slice_9[0][0]']
#  mbda)
#
#  tf.compat.v1.pad_10 (TFOpL  (None, None, None, 16)       0         ['tf.slice_10[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_11 (TFOpL  (None, None, None, 16)       0         ['tf.slice_11[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_12 (TFOpL  (None, None, None, 16)       0         ['tf.slice_12[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_13 (TFOpL  (None, None, None, 16)       0         ['tf.slice_13[0][0]']
#  ambda)
#
#  conv2d_7 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_6[0][0]']
#
#  conv2d_8 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_7[0][0]']
#
#  conv2d_9 (Conv2D)           (None, None, None, 32)       4640      ['tf.compat.v1.pad_8[0][0]']
#
#  conv2d_10 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_10[0][0]']
#
#  conv2d_12 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_11[0][0]']
#
#  conv2d_13 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_12[0][0]']
#
#  conv2d_14 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_13[0][0]']
#
#  leaky_re_lu_6 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_7[0][0]']
#
#  leaky_re_lu_7 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_8[0][0]']
#
#  leaky_re_lu_8 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_9[0][0]']
#
#  leaky_re_lu_9 (LeakyReLU)   (None, None, None, 32)       0         ['conv2d_10[0][0]']
#
#  leaky_re_lu_10 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_11[0][0]']
#
#  leaky_re_lu_11 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_12[0][0]']
#
#  leaky_re_lu_12 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_13[0][0]']
#
#  leaky_re_lu_13 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_14[0][0]']
#
#  tf.slice_14 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_6[0][0]']
#
#  tf.slice_15 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_6[0][0]']
#
#  tf.slice_16 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_7[0][0]']
#
#  tf.slice_17 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_7[0][0]']
#
#  tf.slice_18 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_8[0][0]']
#
#  tf.slice_19 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_8[0][0]']
#
#  tf.slice_20 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_9[0][0]']
#
#  tf.slice_21 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_9[0][0]']
#
#  tf.slice_22 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_10[0][0]']
#
#  tf.slice_23 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_10[0][0]']
#
#  tf.slice_24 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_11[0][0]']
#
#  tf.slice_25 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_11[0][0]']
#
#  tf.slice_26 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_12[0][0]']
#
#  tf.slice_27 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_12[0][0]']
#
#  tf.slice_28 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_13[0][0]']
#
#  tf.slice_29 (TFOpLambda)    (None, None, None, 16)       0         ['leaky_re_lu_13[0][0]']
#
#  tf.compat.v1.pad_14 (TFOpL  (None, None, None, 16)       0         ['tf.slice_14[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_15 (TFOpL  (None, None, None, 16)       0         ['tf.slice_15[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_16 (TFOpL  (None, None, None, 16)       0         ['tf.slice_16[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_17 (TFOpL  (None, None, None, 16)       0         ['tf.slice_17[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_18 (TFOpL  (None, None, None, 16)       0         ['tf.slice_18[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_19 (TFOpL  (None, None, None, 16)       0         ['tf.slice_19[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_20 (TFOpL  (None, None, None, 16)       0         ['tf.slice_20[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_21 (TFOpL  (None, None, None, 16)       0         ['tf.slice_21[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_22 (TFOpL  (None, None, None, 16)       0         ['tf.slice_22[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_23 (TFOpL  (None, None, None, 16)       0         ['tf.slice_23[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_24 (TFOpL  (None, None, None, 16)       0         ['tf.slice_24[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_25 (TFOpL  (None, None, None, 16)       0         ['tf.slice_25[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_26 (TFOpL  (None, None, None, 16)       0         ['tf.slice_26[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_27 (TFOpL  (None, None, None, 16)       0         ['tf.slice_27[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_28 (TFOpL  (None, None, None, 16)       0         ['tf.slice_28[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_29 (TFOpL  (None, None, None, 16)       0         ['tf.slice_29[0][0]']
#  ambda)
#
#  conv2d_15 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_14[0][0]']
#
#  conv2d_16 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_15[0][0]']
#
#  conv2d_17 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_16[0][0]']
#
#  conv2d_18 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_17[0][0]']
#
#  conv2d_19 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_18[0][0]']
#
#  conv2d_20 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_19[0][0]']
#
#  conv2d_21 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_20[0][0]']
#
#  conv2d_22 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_21[0][0]']
#
#  conv2d_23 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_22[0][0]']
#
#  conv2d_24 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_23[0][0]']
#
#  conv2d_25 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_24[0][0]']
#
#  conv2d_26 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_25[0][0]']
#
#  conv2d_27 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_26[0][0]']
#
#  conv2d_28 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_27[0][0]']
#
#  conv2d_29 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_28[0][0]']
#
#  conv2d_30 (Conv2D)          (None, None, None, 32)       4640      ['tf.compat.v1.pad_29[0][0]']
#
#  leaky_re_lu_14 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_15[0][0]']
#
#  leaky_re_lu_15 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_16[0][0]']
#
#  leaky_re_lu_16 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_17[0][0]']
#
#  leaky_re_lu_17 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_18[0][0]']
#
#  leaky_re_lu_18 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_19[0][0]']
#
#  leaky_re_lu_19 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_20[0][0]']
#
#  leaky_re_lu_20 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_21[0][0]']
#
#  leaky_re_lu_21 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_22[0][0]']
#
#  leaky_re_lu_22 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_23[0][0]']
#
#  leaky_re_lu_23 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_24[0][0]']
#
#  leaky_re_lu_24 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_25[0][0]']
#
#  leaky_re_lu_25 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_26[0][0]']
#
#  leaky_re_lu_26 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_27[0][0]']
#
#  leaky_re_lu_27 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_28[0][0]']
#
#  leaky_re_lu_28 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_29[0][0]']
#
#  leaky_re_lu_29 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_30[0][0]']
#
#  tf.compat.v1.pad_30 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_14[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_33 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_15[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_36 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_16[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_39 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_17[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_42 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_18[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_45 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_19[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_48 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_20[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_51 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_21[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_54 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_22[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_57 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_23[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_60 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_24[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_63 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_25[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_66 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_26[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_69 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_27[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_72 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_28[0][0]']
#  ambda)
#
#  tf.compat.v1.pad_75 (TFOpL  (None, None, None, 32)       0         ['leaky_re_lu_29[0][0]']
#  ambda)
#
#  conv2d_31 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_30[0][0]']
#
#  conv2d_35 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_33[0][0]']
#
#  conv2d_39 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_36[0][0]']
#
#  conv2d_43 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_39[0][0]']
#
#  conv2d_47 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_42[0][0]']
#
#  conv2d_51 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_45[0][0]']
#
#  conv2d_55 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_48[0][0]']
#
#  conv2d_59 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_51[0][0]']
#
#  conv2d_63 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_54[0][0]']
#
#  conv2d_67 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_57[0][0]']
#
#  conv2d_71 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_60[0][0]']
#
#  conv2d_75 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_63[0][0]']
#
#  conv2d_79 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_66[0][0]']
#
#  conv2d_83 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_69[0][0]']
#
#  conv2d_87 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_72[0][0]']
#
#  conv2d_91 (Conv2D)          (None, None, None, 32)       9248      ['tf.compat.v1.pad_75[0][0]']
#
#  leaky_re_lu_30 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_31[0][0]']
#
#  leaky_re_lu_32 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_35[0][0]']
#
#  leaky_re_lu_34 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_39[0][0]']
#
#  leaky_re_lu_36 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_43[0][0]']
#
#  leaky_re_lu_38 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_47[0][0]']
#
#  leaky_re_lu_40 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_51[0][0]']
#
#  leaky_re_lu_42 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_55[0][0]']
#
#  leaky_re_lu_44 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_59[0][0]']
#
#  leaky_re_lu_46 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_63[0][0]']
#
#  leaky_re_lu_48 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_67[0][0]']
#
#  leaky_re_lu_50 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_71[0][0]']
#
#  leaky_re_lu_52 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_75[0][0]']
#
#  leaky_re_lu_54 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_79[0][0]']
#
#  leaky_re_lu_56 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_83[0][0]']
#
#  leaky_re_lu_58 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_87[0][0]']
#
#  leaky_re_lu_60 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_91[0][0]']
#
#  global_average_pooling2d (  (None, 32)                   0         ['leaky_re_lu_30[0][0]']
#  GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_32[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_2  (None, 32)                   0         ['leaky_re_lu_34[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_3  (None, 32)                   0         ['leaky_re_lu_36[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_4  (None, 32)                   0         ['leaky_re_lu_38[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_5  (None, 32)                   0         ['leaky_re_lu_40[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_6  (None, 32)                   0         ['leaky_re_lu_42[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_7  (None, 32)                   0         ['leaky_re_lu_44[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_8  (None, 32)                   0         ['leaky_re_lu_46[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_9  (None, 32)                   0         ['leaky_re_lu_48[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_50[0][0]']
#  0 (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_52[0][0]']
#  1 (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_54[0][0]']
#  2 (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_56[0][0]']
#  3 (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_58[0][0]']
#  4 (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['leaky_re_lu_60[0][0]']
#  5 (GlobalAveragePooling2D)
#
#  tf.reshape (TFOpLambda)     (None, 1, 1, 32)             0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  tf.reshape_1 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  tf.reshape_2 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  tf.reshape_3 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_3[0
#                                                                     ][0]']
#
#  tf.reshape_4 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_4[0
#                                                                     ][0]']
#
#  tf.reshape_5 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_5[0
#                                                                     ][0]']
#
#  tf.reshape_6 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_6[0
#                                                                     ][0]']
#
#  tf.reshape_7 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_7[0
#                                                                     ][0]']
#
#  tf.reshape_8 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_8[0
#                                                                     ][0]']
#
#  tf.reshape_9 (TFOpLambda)   (None, 1, 1, 32)             0         ['global_average_pooling2d_9[0
#                                                                     ][0]']
#
#  tf.reshape_10 (TFOpLambda)  (None, 1, 1, 32)             0         ['global_average_pooling2d_10[
#                                                                     0][0]']
#
#  tf.reshape_11 (TFOpLambda)  (None, 1, 1, 32)             0         ['global_average_pooling2d_11[
#                                                                     0][0]']
#
#  tf.reshape_12 (TFOpLambda)  (None, 1, 1, 32)             0         ['global_average_pooling2d_12[
#                                                                     0][0]']
#
#  tf.reshape_13 (TFOpLambda)  (None, 1, 1, 32)             0         ['global_average_pooling2d_13[
#                                                                     0][0]']
#
#  tf.reshape_14 (TFOpLambda)  (None, 1, 1, 32)             0         ['global_average_pooling2d_14[
#                                                                     0][0]']
#
#  tf.reshape_15 (TFOpLambda)  (None, 1, 1, 32)             0         ['global_average_pooling2d_15[
# ...
#  conv2d_transpose_1 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_17[0][0]']
#  Transpose)
#
#  conv2d_transpose_2 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_18[0][0]']
#  Transpose)
#
#  conv2d_transpose_3 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_19[0][0]']
#  Transpose)
#
#  conv2d_transpose_4 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_20[0][0]']
#  Transpose)
#
#  conv2d_transpose_5 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_21[0][0]']
#  Transpose)
#
#  conv2d_transpose_6 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_22[0][0]']
#  Transpose)
#
#  conv2d_transpose_7 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_23[0][0]']
#  Transpose)
#
#  leaky_re_lu_62 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose[0][0]']
#
#  leaky_re_lu_63 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_1[0][0]']
#
#  leaky_re_lu_64 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_2[0][0]']
#
#  leaky_re_lu_65 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_3[0][0]']
#
#  leaky_re_lu_66 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_4[0][0]']
#
#  leaky_re_lu_67 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_5[0][0]']
#
#  leaky_re_lu_68 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_6[0][0]']
#
#  leaky_re_lu_69 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_7[0][0]']
#
#  tf.__operators__.add_32 (T  (None, None, None, 32)       0         ['leaky_re_lu_62[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_6[0][0]']
#
#  tf.__operators__.add_33 (T  (None, None, None, 32)       0         ['leaky_re_lu_63[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_7[0][0]']
#
#  tf.__operators__.add_34 (T  (None, None, None, 32)       0         ['leaky_re_lu_64[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_8[0][0]']
#
#  tf.__operators__.add_35 (T  (None, None, None, 32)       0         ['leaky_re_lu_65[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_9[0][0]']
#
#  tf.__operators__.add_36 (T  (None, None, None, 32)       0         ['leaky_re_lu_66[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_10[0][0]']
#
#  tf.__operators__.add_37 (T  (None, None, None, 32)       0         ['leaky_re_lu_67[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_11[0][0]']
#
#  tf.__operators__.add_38 (T  (None, None, None, 32)       0         ['leaky_re_lu_68[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_12[0][0]']
#
#  tf.__operators__.add_39 (T  (None, None, None, 32)       0         ['leaky_re_lu_69[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_13[0][0]']
#
#  tf.concat_24 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_32[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_33[0][0
#                                                                     ]']
#
#  tf.concat_25 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_34[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_35[0][0
#                                                                     ]']
#
#  tf.concat_26 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_36[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_37[0][0
#                                                                     ]']
#
#  tf.concat_27 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_38[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_39[0][0
#                                                                     ]']
#
#  conv2d_transpose_8 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_24[0][0]']
#  Transpose)
#
#  conv2d_transpose_9 (Conv2D  (None, None, None, 32)       18464     ['tf.concat_25[0][0]']
#  Transpose)
#
#  conv2d_transpose_10 (Conv2  (None, None, None, 32)       18464     ['tf.concat_26[0][0]']
#  DTranspose)
#
#  conv2d_transpose_11 (Conv2  (None, None, None, 32)       18464     ['tf.concat_27[0][0]']
#  DTranspose)
#
#  leaky_re_lu_70 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_8[0][0]']
#
#  leaky_re_lu_71 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_9[0][0]']
#
#  leaky_re_lu_72 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_10[0][0]']
#
#  leaky_re_lu_73 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_11[0][0]']
#
#  tf.__operators__.add_40 (T  (None, None, None, 32)       0         ['leaky_re_lu_70[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_2[0][0]']
#
#  tf.__operators__.add_41 (T  (None, None, None, 32)       0         ['leaky_re_lu_71[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_3[0][0]']
#
#  tf.__operators__.add_42 (T  (None, None, None, 32)       0         ['leaky_re_lu_72[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_4[0][0]']
#
#  tf.__operators__.add_43 (T  (None, None, None, 32)       0         ['leaky_re_lu_73[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_5[0][0]']
#
#  tf.concat_28 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_40[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_41[0][0
#                                                                     ]']
#
#  tf.concat_29 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_42[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_43[0][0
#                                                                     ]']
#
#  conv2d_transpose_12 (Conv2  (None, None, None, 32)       18464     ['tf.concat_28[0][0]']
#  DTranspose)
#
#  conv2d_transpose_13 (Conv2  (None, None, None, 32)       18464     ['tf.concat_29[0][0]']
#  DTranspose)
#
#  leaky_re_lu_74 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_12[0][0]']
#
#  leaky_re_lu_75 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_13[0][0]']
#
#  tf.__operators__.add_44 (T  (None, None, None, 32)       0         ['leaky_re_lu_74[0][0]',
#  FOpLambda)                                                          'leaky_re_lu[0][0]']
#
#  tf.__operators__.add_45 (T  (None, None, None, 32)       0         ['leaky_re_lu_75[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_1[0][0]']
#
#  tf.concat_30 (TFOpLambda)   (None, None, None, 64)       0         ['tf.__operators__.add_44[0][0
#                                                                     ]',
#                                                                      'tf.__operators__.add_45[0][0
#                                                                     ]']
#
#  conv2d_transpose_14 (Conv2  (None, None, None, 32)       18464     ['tf.concat_30[0][0]']
#  DTranspose)
#
#  leaky_re_lu_76 (LeakyReLU)  (None, None, None, 32)       0         ['conv2d_transpose_14[0][0]']
#
#  tf.__operators__.add_46 (T  (None, None, None, 32)       0         ['leaky_re_lu_76[0][0]',
#  FOpLambda)                                                          'conv2d[0][0]']
#
#  conv2d_95 (Conv2D)          (None, None, None, 3)        867       ['tf.__operators__.add_46[0][0
#                                                                     ]']
#
#  tf.__operators__.add_47 (T  (None, None, None, 3)        0         ['input_1[0][0]',
#  FOpLambda)                                                          'conv2d_95[0][0]']
#
# ==================================================================================================
# Total params: 731059 (2.79 MB)
# Trainable params: 731059 (2.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
import tf2onnx
import onnx

# 保存转换后的 ONNX 模型路径
onnx_model_path = "/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/model_weights/SplitterNet_SavedModel.onnx"

# 转换模型
onnx_model, _ = tf2onnx.convert.from_keras(model, opset=13)

# 保存 ONNX 模型
with open(onnx_model_path, "wb") as f:
    f.write(onnx_model.SerializeToString())

print(f"模型已成功转换为 ONNX 格式，并保存到: {onnx_model_path}")
# Out:
# 模型已成功转换为 ONNX 格式，并保存到: /Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/model_weights/SplitterNet_SavedModel.onnx

# %%
import onnx
import onnxruntime as ort
import numpy as np

onnx_model_path = "/Users/curryg/SplitterNet-Efficient-Mobile-Denoising-Models-CVPR2024/model_weights/SplitterNet_SavedModel.onnx"
# 加载 ONNX 模型
onnx_model = onnx.load(onnx_model_path)
onnx.checker.check_model(onnx_model)
print("ONNX 模型验证成功！")

# 推理测试
ort_session = ort.InferenceSession(onnx_model_path)
input_data = np.random.rand(1, 64, 64, 3).astype(np.float32)
outputs = ort_session.run(None, {ort_session.get_inputs()[0].name: input_data})
print(f"ONNX 推理输出形状: {outputs[0].shape}")
# Out:
# ONNX 模型验证成功！
# ONNX 推理输出形状: (1, 64, 64, 3)
